# %%
from tkinter import *

from tkinter.ttk import *
import re
from textblob import TextBlob
from tqdm.auto import tqdm
from tkinter import Label
import time
import pandas as pd
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import time
from selenium.webdriver import ActionChains
from bs4 import BeautifulSoup

# %%
def tentativa(numero_de_tentativas, css_code_selector,driver):
    
    #numero da tentativa atual
    tentativa_atual = 0 
    
    #define um número limite de tentativas
    while tentativa_atual <= numero_de_tentativas:
        
        #tenta clicar no botão
        try:
            driver.find_element_by_css_selector(css_code_selector).click()
            break
        
        #caso não funcione, aumenta a tentativa
        except:
            tentativa_atual += 1
    
    #caso o número de tentativas seja igual ao número limite, não foi possível concluir 
    #a ação
    if tentativa_atual == numero_de_tentativas:
        print("Número de tentativas excedidas")
        
    #caso contrário, informa que passou no teste
    else:
        print("Pass tentativa!")
    
    return

# %%
def acha_lista_de_links(numero_de_tentativas, css_code_selector, driver):
    conta_contratos=2
    conta_paginas=1
    lista_links = []
    #cria uma lista vazia para dar return
    elementos = None
    
    #numero da tentativa atual
    tentativa_atual = 0 
    
    #define um número limite de tentativas
    while tentativa_atual < numero_de_tentativas:
        #lista = driver.find_elements_by_css_selector(css_code_selector)
        #elementos = lista.find_elements_by_class_name("project")
#            print("deu")
        
        #tenta clicar no botão
        try:
            while conta_contratos<=9:
           

                elementos = driver.find_element_by_xpath('/html/body/div[1]/section/main/div/div/sp-page-row/div/div/span/div/div/div[2]/div/div[2]/a['+str(conta_contratos)+']')
                                                          

                link = elementos.get_attribute("href")
                print(link)
                lista_links.append(link)
                conta_contratos+=1
               
            break
        
        #caso não funcione, aumenta a tentativa
        except:
            tentativa_atual += 1
            
    #caso o número de tentativas seja igual ao número limite, não foi possível concluir 
    #a ação
    if tentativa_atual == numero_de_tentativas:
        print("Número de tentativas excedidas")
    
    #caso contrário, informa que passou no teste
    else:
        
        print("Pass acha_lista!")
        #print(elementos[0].text)
        
    return lista_links

# %%
def acha_informacoes(numero_de_tentativas, css_code_selector, driver):
    contador=0
    lista_de_infos=[]
    #cria uma lista vazia para dar return
    elementos = None
    
    #numero da tentativa atual
    tentativa_atual = 0 
    
    #define um número limite de tentativas
    while tentativa_atual < numero_de_tentativas:
        #lista = driver.find_elements_by_css_selector(css_code_selector)
        #elementos = lista.find_elements_by_class_name("project")
#            print("deu")
        
        #tenta clicar no botão
       
        try:
            nome =  driver.find_element_by_xpath('/html/body/div[1]/section/main/div[2]/div/sp-page-row/div/div/span/div/div/div[1]/h2')
            lista_de_infos.append(nome.text)
            
            texto = driver.find_element_by_xpath('/html/body/div[1]/section/main/div[2]/div/sp-page-row/div/div/span/div/div/div[1]/p')
            lista_de_infos.append(texto.text)

            responsavel = driver.find_element_by_xpath('/html/body/div[1]/section/main/div[2]/div/sp-page-row/div/div/span/div/div/div[1]/div[1]/div[1]/div/div[2]')
            lista_de_infos.append(responsavel.text)
            
            setor =driver.find_element_by_xpath('/html/body/div[1]/section/main/div[2]/div/sp-page-row/div/div/span/div/div/div[1]/div[1]/div[2]/div/div[2]')
            lista_de_infos.append(setor.text)
            
            prazo =driver.find_element_by_xpath('/html/body/div[1]/section/main/div[2]/div/sp-page-row/div/div/span/div/div/div[1]/div[1]/div[3]/div/div[2]')
            lista_de_infos.append(prazo.text)
            
            contraprestacao =driver.find_element_by_xpath('/html/body/div[1]/section/main/div[2]/div/sp-page-row/div/div/span/div/div/div[1]/div[2]/div[1]/div/div[2]')
            lista_de_infos.append(contraprestacao.text)
            
            investimento =driver.find_element_by_xpath('/html/body/div[1]/section/main/div[2]/div/sp-page-row/div/div/span/div/div/div[1]/div[2]/div[2]/div/div[2]')
            lista_de_infos.append(investimento.text)
            
            situacao =driver.find_element_by_xpath('/html/body/div[1]/section/main/div[2]/div/sp-page-row/div/div/span/div/div/ul')
            lista_de_infos.append(situacao.text)
            
            evolucao =driver.find_element_by_xpath('/html/body/div[1]/section/main/div[2]/div/sp-page-row/div/div/span/div/div/div[2]/div/div')
            lista_de_infos.append(evolucao.text)
                
            
                
                
                
            break
        
        #caso não funcione, aumenta a tentativa
        except:
            tentativa_atual += 1
            
    #caso o número de tentativas seja igual ao número limite, não foi possível concluir 
    #a ação
    if tentativa_atual == numero_de_tentativas:
        print("Número de tentativas excedidas")
    
    #caso contrário, informa que passou no teste
    else:
        
        print("Pass acha_lista!")
        #print(elementos[0].text)
        
    return lista_de_infos

# %%
n = 1
links = []

while n <= 1:
    url = "https://pppeconcessoes.ba.gov.br/portal_ppp?id=list&table=tsp1_project&filter=&target_page_id=ppp_report&origin=other"
    #cria o webdriver
    driver = webdriver.Chrome(executable_path=r'./chromedriver.exe')

    #pega o conteúdo da url
    driver.get(url)
    
    # driver.find_elements_by_class_name("QvFrame Document_TX2504_224852472")[0].click()

    #tempo para carregar a página inteira
    time.sleep(5)
    
    

    #fecha pop-up
    tentativa(1000, "#ngo > div.ngo-popup > div.got-it", driver)

    lista_de_links = acha_lista_de_links(1000, "#ngo > div.view-content-wrap  > div", driver)

    print(lista_de_links)
    for elemento in lista_de_links:
        links.append(elemento) #(elemento.text)
        
    

    n+=1
    driver.close()
    
print(links)
# Out:
# Pass tentativa!
# https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=ba9a5314dba4d010744ee6ad06961928
# https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=3577af10dbe4d010744ee6ad069619ba
# https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=3e482f04db689010744ee6ad0696193b
# https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=dd2f76b61b268810a1e82fc13b4bcbde
# https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=8f9c1794dba4d010744ee6ad06961950
# https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=a3496784db689010744ee6ad06961948
# https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=4cec0d9f1b92c410a1e82fc13b4bcbf2
# https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=94497ca51be64410a1e82fc13b4bcb59
# Pass acha_lista!
# ['https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=ba9a5314dba4d010744ee6ad06961928', 'https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=3577af10dbe4d010744ee6ad069619ba', 'https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=3e482f04db689010744ee6ad0696193b', 'https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=dd2f76b61b268810a1e82fc13b4bcbde', 'https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=8f9c1794dba4d010744ee6ad06961950', 'https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=a3496784db689010744ee6ad06961948', 'https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=4cec0d9f1b92c410a1e82fc13b4bcbf2', 'https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=94497ca51be64410a1e82fc13b4bcb59']
# ['https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=ba9a5314dba4d010744ee6ad06961928', 'https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=3577af10dbe4d010744ee6ad069619ba', 'https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=3e482f04db689010744ee6ad0696193b', 'https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=dd2f76b61b268810a1e82fc13b4bcbde', 'https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=8f9c1794dba4d010744ee6ad06961950', 'https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=a3496784db689010744ee6ad06961948', 'https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=4cec0d9f1b92c410a1e82fc13b4bcbf2', 'https://pppeconcessoes.ba.gov.br/portal_ppp?id=ppp_report&table=tsp1_project&sys_id=94497ca51be64410a1e82fc13b4bcb59']

# %%
len(links)
# Out:
# 8

# %%
info=0

lista_de_dados=[]

while info<(len(links)):
    url = links[info]
    #cria o webdriver
    driver = webdriver.Chrome(executable_path=r'./chromedriver.exe')

    #pega o conteúdo da url
    driver.get(url)
    
    # driver.find_elements_by_class_name("QvFrame Document_TX2504_224852472")[0].click()

    #tempo para carregar a página inteira
    time.sleep(7)
    
    

    #fecha pop-up
    tentativa(1000, "#ngo > div.ngo-popup > div.got-it", driver)

    dados = acha_informacoes(1000, "#ngo > div.parcerias_tb_dados_parceria > div", driver)


    
    lista_de_dados.append(dados) #(elemento.text)
    
    

    info+=1
    driver.close()
    
    
print(lista_de_dados)
# Out:
# Pass tentativa!
# Pass acha_lista!
# Pass tentativa!
# Pass acha_lista!
# Pass tentativa!
# Pass acha_lista!
# Pass tentativa!
# Pass acha_lista!
# Pass tentativa!
# Pass acha_lista!
# Pass tentativa!
# Pass acha_lista!
# Pass tentativa!
# Pass acha_lista!
# Pass tentativa!
# Pass acha_lista!
# [['Veículo Leve sobre Trilhos (VLT)', 'O Projeto consiste na concessão patrocinada para implantação das obras civis e sistemas, fornecimento do material rodante, operação e manutenção do Veículo Leve sobre Trilhos ou outro modal equivalente de transporte público sobre trilho ou guia e movido à propulsão elétrica (VLT do Subúrbio), tendo como principal objetivo a integração entre o Subúrbio e os principais corredores de transporte público de massa da cidade de Salvador, com 19,9 quilômetros de extensão ao longo de 22 estações, substituindo o atual trem do Subúrbio.', 'SEDUR - Secretaria de Desenvolvimento Urbano', 'Transportes Públicos', '35 anos', 'R$ 152.977.352,17', 'Sem CAPEX', 'Estudos Consulta Pública Licitação Assinatura do Contrato', '0%'], ['Sistema Rodoviário BA052 (Estrada do Feijão)', 'O projeto visa a reabilitação e manutenção ("brownfield") em um trecho de 462 km da Rodovia BA052, que liga Feira de Santana a Xique-Xique; 85 km da Rodovia BA160, que liga Xique-Xique à Ponte; e, adicionalmente, a construção de uma Ponte ("greenfield") de 1 km ligando os municípios de Xique-Xique à Barra. O objeto é a delegação, por meio de parceria público-privada, na modalidade de concessão patrocinada, das obras e dos Serviços necessários para a operação, manutenção e revitalização do Sistema BA052.', 'SEINFRA - Secretaria de Infraestrutura', 'Rodovias', '20 anos', 'R$ 0,00', 'Sem CAPEX', 'Estudos Consulta Pública Licitação Assinatura do Contrato', '0%'], ['Sistema Metroviário de Salvador e Lauro de Freitas', 'Este projeto visa a implantação e operação do Sistema Metroviário de Salvador e Lauro de Freitas, por meio de concessão patrocinada, abrangendo a construção da linha 2 do metrô e conclusão das obras da linha 1, interligando os municípios de Salvador e Lauro de Freitas, com extensão total de cerca de 36 km.', 'SEDUR - Secretaria de Desenvolvimento Urbano', 'Transportes Públicos', '30 anos', 'R$ 127.600.000,00', 'Sem CAPEX', 'Estudos Consulta Pública Licitação Assinatura do Contrato', '100%'], ['Projeto diagnóstico por imagem', 'Gestão e operação de Serviço de Apoio ao Diagnóstico por Imagem em uma Central de Imagem e em 12 Unidades Hospitalares integrantes da Rede Própria da Secretaria de Saúde do Estado. O projeto tem como objetivo a prestação de Serviços de Apoio ao Diagnóstico, em regime de PPP, para o provimento dos serviços de telemedicina e bioimagem, em elevadas condições de qualidade e acessibilidade. O prazo da concessão será de 11 anos e 6 meses, contado a partir da data da assinatura do contrato de concessão.', 'SESAB - Secretaria da Saúde', 'Saúde', '12 anos', 'R$ 6.821.879,75', 'Sem CAPEX', 'Estudos Consulta Pública Licitação Assinatura do Contrato', '100%'], ['Hospital do Suburbio', 'O projeto visa implementar no hospital geral público estadual a gestão privada, afim de ofertar atendimento gratuito com alta qualidade. O Hospital é classificado como um hospital público de porta aberta, com foco em atendimentos de urgência e emergência em alta complexidade, conta com centro de bioimagem, raios X, tomógrafo, ultrassonografia, ressonância magnética e endoscopia, dentre outros. Está localizado no bairro de Periperi, em Salvador (Bahia), na região do Subúrbio Ferroviário.', 'SESAB - Secretaria da Saúde', 'Saúde', '10 anos', 'R$ 6.821.879,00', 'Sem CAPEX', 'Estudos Consulta Pública Licitação Assinatura do Contrato', '100%'], ['Emissário Submarino', 'O projeto visa a construção e operação da Sistema de Disposição Oceânica do Jaguaribe, parte integrante do Programa de Ampliação de Esgotamento Sanitário da cidade de Salvador. O projeto compreende a ampliação da Estação Elevatória do Saboeiro, implantação de linhas de recalque, construção de Estação de Condicionamento Prévio e implantação dos Emissários Terrestre e Submarino.', 'EMBASA -Secretaria de Águas e Saneamento', 'Saneamento', '18 anos', 'R$ 0,00', 'Sem CAPEX', 'Estudos Consulta Pública Licitação Assinatura do Contrato', '100%'], ['Arena Fonte Nova', 'Concessão adm ...

# %%
nome =  []  
texto = [] 
responsavel =[] 
setor =[] 
prazo =[] 
contraprestacao =[] 
investimento =[] 
situacao =[] 
evolucao =[] 



for listas in lista_de_dados:
    nome.append(listas[0])
    texto.append(listas[1])
    responsavel.append(listas[2])
    setor.append(listas[3])
    prazo.append(listas[4])
    contraprestacao.append(listas[5])
    investimento.append(listas[6])
    situacao.append(listas[7])
    evolucao.append(listas[8])
    
dicionario = {}
dicionario["Nome"] = nome
dicionario["Texto"] = texto
dicionario["Resonsável pelo projeto"] = responsavel
dicionario["Setor"] = setor
dicionario["Prazo"] = prazo
dicionario["Contraprestação/Outorga"] = contraprestacao
dicionario["Investimentos (CAPEX)"] = investimento
dicionario["Situação"] = situacao
dicionario["Evolução"] = evolucao




resultado = pd.DataFrame(data=dicionario)


resultado.to_excel('Bahia.xlsx', index = False)
