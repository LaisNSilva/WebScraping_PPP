# %%
from tkinter import *

from tkinter.ttk import *
import re
from textblob import TextBlob
from tqdm.auto import tqdm
from tkinter import Label
import time
import pandas as pd
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import time
from selenium.webdriver import ActionChains
from bs4 import BeautifulSoup

# %%
def tentativa(numero_de_tentativas, css_code_selector,driver):
    
    #numero da tentativa atual
    tentativa_atual = 0 
    
    #define um número limite de tentativas
    while tentativa_atual <= numero_de_tentativas:
        
        #tenta clicar no botão
        try:
            driver.find_element_by_css_selector(css_code_selector).click()
            break
        
        #caso não funcione, aumenta a tentativa
        except:
            tentativa_atual += 1
    
    #caso o número de tentativas seja igual ao número limite, não foi possível concluir 
    #a ação
    if tentativa_atual == numero_de_tentativas:
        print("Número de tentativas excedidas")
        
    #caso contrário, informa que passou no teste
    else:
        print("Pass tentativa!")
    
    return

# %%
def acha_lista_de_links(numero_de_tentativas, css_code_selector, driver):
    conta_contratos=1
    conta_paginas=1
    lista_links = []
    #cria uma lista vazia para dar return
    elementos = None
    
    #numero da tentativa atual
    tentativa_atual = 0 
    
    #define um número limite de tentativas
    while tentativa_atual < numero_de_tentativas:
        #lista = driver.find_elements_by_css_selector(css_code_selector)
        #elementos = lista.find_elements_by_class_name("project")
#            print("deu")
        
        #tenta clicar no botão
        try:
            
           
            while conta_contratos<=4:
                elementos = driver.find_element_by_xpath('/html/body/div[2]/section[3]/div/div/div[2]/main/div[3]/div/div/div/div/section/article/div/table/tbody/tr['+str(conta_contratos)+']/td/h6/a')


                link = elementos.get_attribute("href")
                print(link)
                lista_links.append(link)
                conta_contratos+=1
               
            break
        
        #caso não funcione, aumenta a tentativa
        except:
            tentativa_atual += 1
            
    #caso o número de tentativas seja igual ao número limite, não foi possível concluir 
    #a ação
    if tentativa_atual == numero_de_tentativas:
        print("Número de tentativas excedidas")
    
    #caso contrário, informa que passou no teste
    else:
        
        print("Pass acha_lista!")
        #print(elementos[0].text)
        
    return lista_links

# %%
def acha_informacoes(numero_de_tentativas, css_code_selector, driver):
    contador=0
    lista_de_infos=[]
    #cria uma lista vazia para dar return
    elementos = None
    
    #numero da tentativa atual
    tentativa_atual = 0 
    
    #define um número limite de tentativas
    while tentativa_atual < numero_de_tentativas:
        #lista = driver.find_elements_by_css_selector(css_code_selector)
        #elementos = lista.find_elements_by_class_name("project")
#            print("deu")
        
        #tenta clicar no botão
       
        try:
            nome =  driver.find_element_by_xpath('/html/body/div[2]/section[3]/div/div/div[2]/main/div[3]/div/div/div/div/section/article/h1')
            lista_de_infos.append(nome.text)
            
            grupo_de_trabalho = driver.find_element_by_xpath('/html/body/div[2]/section[3]/div/div/div[2]/main/div[3]/div/div/div/div/section/article/div/table[1]/tbody/tr/td/p')
            lista_de_infos.append(grupo_de_trabalho.text)

            setor = driver.find_element_by_xpath('/html/body/div[2]/section[3]/div/div/div[2]/main/div[3]/div/div/div/div/section/article/div/table[2]/tbody/tr/td/p')
            lista_de_infos.append(setor.text)
            
            objeto =driver.find_element_by_xpath('/html/body/div[2]/section[3]/div/div/div[2]/main/div[3]/div/div/div/div/section/article/div/table[3]/tbody/tr/td/p')
            lista_de_infos.append(objeto.text)
            
            anexo =driver.find_element_by_xpath('/html/body/div[2]/section[3]/div/div/div[2]/main/div[3]/div/div/div/div/section/article/div/table[4]/tbody/tr/td')
            lista_de_infos.append(anexo.text)
                
            
                
                
                
            break
        
        #caso não funcione, aumenta a tentativa
        except:
            tentativa_atual += 1
            
    #caso o número de tentativas seja igual ao número limite, não foi possível concluir 
    #a ação
    if tentativa_atual == numero_de_tentativas:
        print("Número de tentativas excedidas")
    
    #caso contrário, informa que passou no teste
    else:
        
        print("Pass acha_lista!")
        #print(elementos[0].text)
        
    return lista_de_infos

# %%
n = 1
#links = []



while n <= 1:
    url = "https://www.goiasparcerias.go.gov.br/projetos/estudo-de-viabilidade.html"
    #cria o webdriver
    driver = webdriver.Chrome(executable_path=r'./chromedriver.exe')

    #pega o conteúdo da url
    driver.get(url)
    
    # driver.find_elements_by_class_name("QvFrame Document_TX2504_224852472")[0].click()

    #tempo para carregar a página inteira
    time.sleep(5)
    
    

    #fecha pop-up
    tentativa(1000, "#ngo > div.ngo-popup > div.got-it", driver)

    lista_de_links = acha_lista_de_links(1000, "#ngo > div.view-content-wrap  > div", driver)

    print(lista_de_links)
    for elemento in lista_de_links:
        links.append(elemento) #(elemento.text)
        
    

    n+=1
    driver.close()
    
print(links)
# Out:
# Pass tentativa!
# https://www.goiasparcerias.go.gov.br/projetos/estudo-de-viabilidade.html?view=article&id=228&catid=2
# https://www.goiasparcerias.go.gov.br/projetos/estudo-de-viabilidade.html?view=article&id=229&catid=2
# https://www.goiasparcerias.go.gov.br/projetos/estudo-de-viabilidade.html?view=article&id=232&catid=2
# https://www.goiasparcerias.go.gov.br/projetos/estudo-de-viabilidade.html?view=article&id=230&catid=2
# Pass acha_lista!
# ['https://www.goiasparcerias.go.gov.br/projetos/estudo-de-viabilidade.html?view=article&id=228&catid=2', 'https://www.goiasparcerias.go.gov.br/projetos/estudo-de-viabilidade.html?view=article&id=229&catid=2', 'https://www.goiasparcerias.go.gov.br/projetos/estudo-de-viabilidade.html?view=article&id=232&catid=2', 'https://www.goiasparcerias.go.gov.br/projetos/estudo-de-viabilidade.html?view=article&id=230&catid=2']
# ['https://www.goiasparcerias.go.gov.br/projetos/intencao-publica.html?view=article&id=216&catid=2', 'https://www.goiasparcerias.go.gov.br/projetos/intencao-publica.html?view=article&id=233&catid=2', 'https://www.goiasparcerias.go.gov.br/projetos/proposta-preliminar.html?view=article&id=217&catid=2', 'https://www.goiasparcerias.go.gov.br/projetos/proposta-preliminar.html?view=article&id=218&catid=2', 'https://www.goiasparcerias.go.gov.br/projetos/proposta-preliminar.html?view=article&id=219&catid=2', 'https://www.goiasparcerias.go.gov.br/projetos/proposta-preliminar.html?view=article&id=220&catid=2', 'https://www.goiasparcerias.go.gov.br/projetos/proposta-preliminar.html?view=article&id=221&catid=2', 'https://www.goiasparcerias.go.gov.br/projetos/proposta-preliminar.html?view=article&id=224&catid=2', 'https://www.goiasparcerias.go.gov.br/projetos/proposta-preliminar.html?view=article&id=226&catid=2', 'https://www.goiasparcerias.go.gov.br/projetos/estudo-de-viabilidade.html?view=article&id=228&catid=2', 'https://www.goiasparcerias.go.gov.br/projetos/estudo-de-viabilidade.html?view=article&id=229&catid=2', 'https://www.goiasparcerias.go.gov.br/projetos/estudo-de-viabilidade.html?view=article&id=232&catid=2', 'https://www.goiasparcerias.go.gov.br/projetos/estudo-de-viabilidade.html?view=article&id=230&catid=2']

# %%
len(links)
# Out:
# 13

# %%
info=0

lista_de_dados=[]

while info<(len(links)):
    url = links[info]
    #cria o webdriver
    driver = webdriver.Chrome(executable_path=r'./chromedriver.exe')

    #pega o conteúdo da url
    driver.get(url)
    
    # driver.find_elements_by_class_name("QvFrame Document_TX2504_224852472")[0].click()

    #tempo para carregar a página inteira
    time.sleep(7)
    
    

    #fecha pop-up
    tentativa(1000, "#ngo > div.ngo-popup > div.got-it", driver)

    dados = acha_informacoes(1000, "#ngo > div.parcerias_tb_dados_parceria > div", driver)
    
    if info<2:
        dados.append("Intenção Pública")
    elif info>=2 and info<9:
        dados.append("Proposta Preliminar")
    else:
        dados.append("Estudo de Viabilidade")
        


    
    lista_de_dados.append(dados) #(elemento.text)
    
    

    info+=1
    driver.close()
    
    
print(lista_de_dados)
# Out:
# Pass tentativa!
# Pass acha_lista!
# Pass tentativa!
# Pass acha_lista!
# Pass tentativa!
# Pass acha_lista!
# Pass tentativa!
# Pass acha_lista!
# Pass tentativa!
# Número de tentativas excedidas
# Pass tentativa!
# Pass acha_lista!
# Pass tentativa!
# Pass acha_lista!
# Pass tentativa!
# Pass acha_lista!
# Pass tentativa!
# Pass acha_lista!
# Pass tentativa!
# Pass acha_lista!
# Pass tentativa!
# Pass acha_lista!
# Pass tentativa!
# Pass acha_lista!
# Pass tentativa!
# Pass acha_lista!
# [['Aeroporto de Cargas de Anápolis', 'Goiás Parcerias, Secretaria-Geral da Governadoria (SGG), Companhia de Desenvolvimento Econômico de Goiás (Codego), Agência Goiana de Infraestrutura e Transportes (Goinfra), Secretaria de Estado de Indústria, Comércio e Serviços (SIC).', 'Aeroportuário', 'Subconcessão do Aeroporto de Cargas de Anápolis.', 'Anexos:', 'Intenção Pública'], ['Centrais de Abastecimento de Goiás - Ceasa-GO', 'Goiás Parcerias, Centrais de Abastecimento de Goiás (Ceasa-GO).', 'Centrais de Abastecimento.', 'Concessão de uso das centrais de abastecimento.', 'Anexos:', 'Intenção Pública'], ['Centro Cultural Oscar Niemeyer - CCON', 'Goiás Parcerias, Goiás Turismo, CCON, Secretaria de Estado de Indústria, Comércio e Serviços (SIC) e Secretaria de Estado da Administração (Sead).', 'Cultural.', 'Concessão do Centro Cultural Oscar Niemeyer.', 'Anexos:', 'Proposta Preliminar'], ['Indústria Química do Estado de Goiás - Iquego', 'Goiás Parcerias, Iquego, Secretaria de Estado da Saúde (SES-GO), Secretaria de Estado da Economia.', 'Indústria Farmacêutica', 'Estudo de alienação das ações subscritas da Iquego.', 'Anexos:', 'Proposta Preliminar'], ['Metrobus Transporte Coletivo S/A', 'Goiás Parcerias, Metrobus, Secretaria de Estado de Desenvolvimento e Inovação (Sedi), Secretaria de Estado da Economia.', 'Mobilidade - Transporte', 'Metrobus Transporte Coletivo S/A', 'Goiás Parcerias, Metrobus, Secretaria de Estado de Desenvolvimento e Inovação (Sedi), Secretaria de Estado da Economia.', 'Mobilidade - Transporte', 'Metrobus Transporte Coletivo S/A', 'Goiás Parcerias, Metrobus, Secretaria de Estado de Desenvolvimento e Inovação (Sedi), Secretaria de Estado da Economia.', 'Mobilidade - Transporte', 'Metrobus Transporte Coletivo S/A', 'Goiás Parcerias, Metrobus, Secretaria de Estado de Desenvolvimento e Inovação (Sedi), Secretaria de Estado da Economia.', 'Mobilidade - Transporte', 'Metrobus Transporte Coletivo S/A', 'Goiás Parcerias, Metrobus, Secretaria de Estado de Desenvolvimento e Inovação (Sedi), Secretaria de Estado da Economia.', 'Mobilidade - Transporte', 'Metrobus Transporte Coletivo S/A', 'Goiás Parcerias, Metrobus, Secretaria de Estado de Desenvolvimento e Inovação (Sedi), Secretaria de Estado da Economia.', 'Mobilidade - Transporte', 'Metrobus Transporte Coletivo S/A', 'Goiás Parcerias, Metrobus, Secretaria de Estado de Desenvolvimento e Inovação (Sedi), Secretaria de Estado da Economia.', 'Mobilidade - Transporte', 'Metrobus Transporte Coletivo S/A', 'Goiás Parcerias, Metrobus, Secretaria de Estado de Desenvolvimento e Inovação (Sedi), Secretaria de Estado da Economia.', 'Mobilidade - Transporte', 'Metrobus Transporte Coletivo S/A', 'Goiás Parcerias, Metrobus, Secretaria de Estado de Desenvolvimento e Inovação (Sedi), Secretaria de Estado da Economia.', 'Mobilidade - Transporte', 'Metrobus Transporte Coletivo S/A', 'Goiás Parcerias, Metrobus, Secretaria de Estado de Desenvolvimento e Inovação (Sedi), Secretaria de Estado da Economia.', 'Mobilidade - Transporte', 'Metrobus Transporte Coletivo S/A', 'Goiás Parcerias, Metrobus, Secretaria de Estado de Desenvolvimento e Inovação (Sedi), Secretaria de Estado da Economia.', 'Mobilidade - Transporte', 'Metrobus Transporte Coletivo S/A', 'Goiás Parcerias, Metrobus, Secretaria de Estado de Desenvolvimento e Inovação (Sedi), Secretaria de Estado da Economia.', 'Mobilidade - Transporte', 'Metrobus Transporte Coletivo S/A', 'Goiás Parcerias, Metrobus, Secretaria de Estado de Desenvolvimento e Inovação (Sedi), Secretaria de Estado da Economia.', 'Mobilidade - Transporte', 'Metrobus Transporte Coletivo S/A', 'Goiás Parcerias, Metrobus, Secretaria de Estado de Desenvolvimento e Inovação (Sedi), Secretaria de Estado da Economia.', 'Mobilidade - Transporte', 'Metrobus Transporte Coletivo S/A', 'Goiás Parcerias, Metrobus, Secretaria de Estado de Desenvolvimento e Inovação (Sedi), Secretaria de Estado da Economia.', 'Mobilidade - Transporte', 'Metrobus Transporte Coletivo S/A', 'Goiás Parc ...

# %%
len(lista_de_dados)
# Out:
# 13

# %%
nome = []
grupo_de_trabalho = []
setor = []
objeto =[]
anexo =[]
tipo=[]



for listas in lista_de_dados:
    nome.append(listas[0])
    grupo_de_trabalho.append(listas[1])
    setor.append(listas[2])
    objeto.append(listas[3])
    anexo.append(listas[4])
    tipo.append(listas[5])
    
    
dicionario = {}
dicionario["Nome"] = nome
dicionario["Grupo de Trabalho"] = grupo_de_trabalho
dicionario["Setor"] = setor
dicionario["Objeto"] = objeto
dicionario["Anexo"] = anexo
dicionario["Tipo"] = tipo




resultado = pd.DataFrame(data=dicionario)


resultado.to_excel('Goias.xlsx', index = False)
