# %%
from tkinter import *

from tkinter.ttk import *
import re
from textblob import TextBlob
from tqdm.auto import tqdm
from tkinter import Label
import time
import pandas as pd
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import time
from selenium.webdriver import ActionChains
from bs4 import BeautifulSoup

# %%
def tentativa(numero_de_tentativas, css_code_selector,driver):
    
    #numero da tentativa atual
    tentativa_atual = 0 
    
    #define um número limite de tentativas
    while tentativa_atual <= numero_de_tentativas:
        
        #tenta clicar no botão
        try:
            driver.find_element_by_css_selector(css_code_selector).click()
            break
        
        #caso não funcione, aumenta a tentativa
        except:
            tentativa_atual += 1
    
    #caso o número de tentativas seja igual ao número limite, não foi possível concluir 
    #a ação
    if tentativa_atual == numero_de_tentativas:
        print("Número de tentativas excedidas")
        
    #caso contrário, informa que passou no teste
    else:
        print("Pass tentativa!")
    
    return

# %%
def acha_lista_de_links(numero_de_tentativas, css_code_selector, driver):
    conta_contratos=1
    conta_paginas=1
    lista_links = []
    #cria uma lista vazia para dar return
    elementos = None
    
    #numero da tentativa atual
    tentativa_atual = 0 
    
    #define um número limite de tentativas
    while tentativa_atual < numero_de_tentativas:
        #lista = driver.find_elements_by_css_selector(css_code_selector)
        #elementos = lista.find_elements_by_class_name("project")
#            print("deu")
        
        #tenta clicar no botão
        try:
            
                        
            while(conta_paginas<=4):
                conta_contratos=1
                while(conta_contratos<=10):
                    
                    elementos = driver.find_element_by_xpath('/html/body/div[2]/div[3]/div[3]/div[2]/div/table/tbody/tr[1]['+str(conta_contratos)+'10]/td[1]/a')
                                                               
                    link = elementos.get_attribute("href")
                    print(link)
                    lista_links.append(link)
                    conta_contratos+=1
                    
                print('vou clicar') 
               
                cliquei=driver.find_element_by_xpath('/html/body/div[2]/div[3]/div[3]/div[2]/div/div[2]/div[2]/div/ul/li[6]/a').click()
                                                        
                    
                time.sleep(3)
                conta_paginas+=1
                    
                    
            break
        
        #caso não funcione, aumenta a tentativa
        except:
            tentativa_atual += 1
            
    #caso o número de tentativas seja igual ao número limite, não foi possível concluir 
    #a ação
    if tentativa_atual == numero_de_tentativas:
        print("Número de tentativas excedidas")
    
    #caso contrário, informa que passou no teste
    else:
        
        print("Pass acha_lista!")
        #print(elementos[0].text)
        
    return lista_links

# %%
def acha_informacoes(numero_de_tentativas, css_code_selector, driver):
    contador=0
    lista_de_infos=[]
    #cria uma lista vazia para dar return
    elementos = None
    
    #numero da tentativa atual
    tentativa_atual = 0 
    
    #define um número limite de tentativas
    while tentativa_atual < numero_de_tentativas:
        #lista = driver.find_elements_by_css_selector(css_code_selector)
        #elementos = lista.find_elements_by_class_name("project")
#            print("deu")
        
        #tenta clicar no botão
       
        try:
            nome =  driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[2]/div[1]/div/div/div/div/div/div/h2')
            lista_de_infos.append(nome.text)
            
            infos = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[2]/div[2]/div/div[1]/div/div/div[1]/div')
            lista_de_infos.append(infos.text)

            
            informacoes_preliminares = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[2]/div[2]/div/div[1]/div/div/div[3]')
            lista_de_infos.append(informacoes_preliminares.text)
            
            modalidade_contratacao =driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[2]/div[3]/div/div[1]/div/div/div[2]/div/p')
            lista_de_infos.append(modalidade_contratacao.text)
            
            referencias =driver.find_element_by_xpath('/html/body/div[1]/div[2]/div/div/div/div[2]/div[3]/div/div[2]/div/div/div[2]/div')
            lista_de_infos.append(referencias.text)
            

                
            
                
                
                
            break
        
        #caso não funcione, aumenta a tentativa
        except:
            tentativa_atual += 1
            
    #caso o número de tentativas seja igual ao número limite, não foi possível concluir 
    #a ação
    if tentativa_atual == numero_de_tentativas:
        print("Número de tentativas excedidas")
    
    #caso contrário, informa que passou no teste
    else:
        
        print("Pass acha_lista!")
        #print(elementos[0].text)
        
    return lista_de_infos

# %%
links=['https://parcerias.al.gov.br/projeto-abatedouro-de-vicosa/', 'https://parcerias.al.gov.br/projeto-central-de-abastecimento-de-maceio/', 'https://parcerias.al.gov.br/projeto-canal-do-sertao/', 'https://parcerias.al.gov.br/projeto-saneamento-basico/', 'https://parcerias.al.gov.br/projeto-aeroporto-de-maragogi/', 'https://parcerias.al.gov.br/projeto-porto-coruripe/', 'https://parcerias.al.gov.br/projeto-geracao-de-energia-solar/', 'https://parcerias.al.gov.br/projeto-creches/', 'https://parcerias.al.gov.br/projeto-mercado-do-jaragua/', 'https://parcerias.al.gov.br/projeto-polo-tecnologico/']

# %%
info=0

lista_de_dados=[]

while info<1: #(len(links)):
    #url = links[info]
    url = 'https://parcerias.al.gov.br/projeto-abatedouro-de-vicosa/'
    #cria o webdriver
    driver = webdriver.Chrome(executable_path=r'./chromedriver.exe')

    #pega o conteúdo da url
    driver.get(url)
    
    # driver.find_elements_by_class_name("QvFrame Document_TX2504_224852472")[0].click()

    #tempo para carregar a página inteira
    time.sleep(7)
    
    

    #fecha pop-up
    tentativa(1000, "#ngo > div.ngo-popup > div.got-it", driver)

    dados = acha_informacoes(1000, "#ngo > div.parcerias_tb_dados_parceria > div", driver)


    
    lista_de_dados.append(dados) #(elemento.text)
    
    

    info+=1
    driver.close()
    
    
print(lista_de_dados)
